# %% [markdown]
# Function : function is a block of code that code are used to again again.
#     function provieds reussability.
#
#     function reduse our code. using of function we can reuse our code.
#
#     in python function is define by def ketword.
#
# There are 2 step to use fuction
#
# 1) Function defination
#
#         syntax:
#
#             def <fun_name>():
#                 block of code
#
# 2) function calling or function use
#
#         syntax :
#
#             fun_name()

# %%
def a():
    print("hi rishi")

a()
a()
# Out:
# hi rishi
# hi rishi
